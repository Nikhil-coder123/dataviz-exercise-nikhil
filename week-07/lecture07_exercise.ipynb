# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv('netflix_catalogue.csv')
print(f"Loaded: {len(df)} titles")
print(df['type'].value_counts())
print(df.head())
# Out:
# Loaded: 3000 titles
# type
# Movie      1974
# TV Show    1026
# Name: count, dtype: int64
#       type  release_year  added_year             genre        country rating  \
# 0    Movie          2014        2016  Sci-Fi & Fantasy         France  PG-13
# 1    Movie          2010        2014     Documentaries  United States  TV-MA
# 2  TV Show          2011        2012     Kids & Family  United States  TV-14
# 3    Movie          2016        2018             Anime          India     PG
# 4    Movie          2014        2016     Kids & Family         Canada  TV-MA
#
#    duration
# 0       157
# 1       127
# 2         6
# 3       134
# 4        77

# %%
print("Genres:", df['genre'].value_counts().head(8))
print("\nCountries:", df['country'].value_counts().head(8))
print("\nRatings:", df['rating'].value_counts())
# Out:
# Genres: genre
# Sports                244
# Sci-Fi & Fantasy      213
# Kids & Family         209
# Crime                 206
# Drama                 204
# Horror                199
# Action & Adventure    198
# Thrillers             195
# Name: count, dtype: int64
#
# Countries: country
# United States     932
# India             337
# United Kingdom    261
# Japan             187
# France            176
# Canada            164
# South Korea       151
# Mexico            138
# Name: count, dtype: int64
#
# Ratings: rating
# TV-MA    840
# TV-14    733
# PG-13    589
# R        312
# PG       196
# TV-PG    128
# G         92
# TV-Y7     57
# TV-G      53
# Name: count, dtype: int64

# %% [markdown]
# Task 1 — **Heatmap**

# %%
df['decade'] = (df['release_year'] // 10 * 10).astype(str) + 's'


top_ratings = df['rating'].value_counts().nlargest(8).index

filtered = df[df['rating'].isin(top_ratings)]


rating_decade = (
    filtered.groupby(['rating', 'decade'])
    .size()
    .reset_index(name='count')
)


pivot = rating_decade.pivot(
    index='rating',
    columns='decade',
    values='count'
).fillna(0)


fig = px.imshow(
    pivot,
    text_auto=True,
    color_continuous_scale='YlOrRd',
    aspect='auto',
    title='Netflix Content by Rating and Release Decade'
)


fig.update_layout(
    width=1000,
    height=600,
    xaxis_title='Release Decade',
    yaxis_title='Content Rating',
    title_x=0.5
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Task 2 — Waterfall **Chart** bold text

# %%
# Import libraries
import pandas as pd
import plotly.graph_objects as go

# Load dataset
df = pd.read_csv('netflix_catalogue.csv')

# Filter only Movies
movies = df[df['type'] == 'Movie']

# Group by added year
adds = (
    movies.groupby('added_year')
    .size()
    .reset_index(name='new_titles')
)

# Keep years between 2015 and 2022
adds = adds[
    (adds['added_year'] >= 2015) &
    (adds['added_year'] <= 2022)
]

# Calculate total movies added
cumulative = adds['new_titles'].sum()

# Create Waterfall Chart
fig = go.Figure(go.Waterfall(

    x=[str(year) for year in adds['added_year']] + ['Total'],

    y=adds['new_titles'].tolist() + [cumulative],

    measure=['relative'] * len(adds) + ['total'],

    text=adds['new_titles'].tolist() + [cumulative],

    textposition='outside',

    connector=dict(
        line=dict(
            color='#AAAAAA',
            dash='dot'
        )
    ),

    increasing=dict(
        marker_color='#70AD47'
    ),

    totals=dict(
        marker_color='#2E75B6'
    )
))

# Layout
fig.update_layout(

    title='Growth of Netflix Movie Library (2015–2022)',

    xaxis_title='Year',

    yaxis_title='Number of Movies Added',

    width=1000,

    height=600,

    title_x=0.5
)

# Show chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
